# %% [markdown]
# ## Kecepatan Face Detection

# %% [markdown]
# ###  Face Detection Speed MTCNN + FaceNet

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal1 = 0

def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal1
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
		#t1_stop = process_time()
	stop = timeit.default_timer()
		
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal1 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal1)
	
	return face_array
		
		
	
@tf.autograph.experimental.do_not_convert
# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/1/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E748D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E748D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895379798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895379798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E78DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E78DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E78DC8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# elapsed time:  74.6720015 66.4530688
# elapsed time in seconds in face detection dengan 100 gambar : 8.218933
# hasil total: 8.218933 detik
# hasil tambahfinal:  8.218933
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950E28B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950E28B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950E28B8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF25CE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF25CE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950E2F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950E2F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  76.6220101 74.6753911
# elapsed time in seconds in face detection dengan 100 gambar : 1.946619
# hasil total: 10.165552 detik
# hasil tambahfinal:  10.165552
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8BD9718B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8BD9718B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E99AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E99AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89537B9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89537B9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  77.7382779 76.6231725
# elapsed time in seconds in face detection dengan 100 gambar : 1.115105
# hasil total: 11.280657 detik
# hasil tambahfinal:  11.280657
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895074B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895074B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6BE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6BE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B85543A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B85543A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  78.7619776 77.7396368
# elapsed time in seconds in face detection dengan 100 gambar : 1.022341
# hasil total: 12.302998 detik
# hasil tambahfinal:  12.302998
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E4DDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E4DDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF75BB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF75BB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EEB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EEB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  79.8261866 78.7634678
# elapsed time in seconds in face detection dengan 100 gambar : 1.062719
# hasil total: 13.365717 detik
# hasil tambahfinal:  13.365717
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3E7D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3E7D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF16798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF16798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF5FDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF5FDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  80.8983943 79.8278624
# elapsed time in seconds in face detection dengan 100 gambar : 1.070532
# hasil total: 14.436249 detik
# hasil tambahfinal:  14.436249
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC56CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC56CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F9DB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F9DB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC568B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC568B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  81.7386645 80.8994523
# elapsed time in seconds in face detection dengan 100 gambar : 0.839212
# hasil total: 15.275461 detik
# hasil tambahfinal:  15.275461
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF75BF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF75BF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1E798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1E798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E591DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E591DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  82.7639908 81.7399309
# elapsed time in seconds in face detection dengan 100 gambar : 1.024060
# hasil total: 16.299521 detik
# hasil tambahfinal:  16.299521
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9469149D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9469149D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505E5EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505E5EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9469145E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9469145E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  83.7818898 82.7657059
# elapsed time in seconds in face detection dengan 100 gambar : 1.016184
# hasil total: 17.315705 detik
# hasil tambahfinal:  17.315705
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505E5E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505E5E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9AF798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9AF798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA03DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA03DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  84.8453961 83.7829132
# elapsed time in seconds in face detection dengan 100 gambar : 1.062483
# hasil total: 18.378188 detik
# hasil tambahfinal:  18.378188
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951072708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951072708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9629409D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9629409D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962954D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962954D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  86.0429649 84.8466688
# elapsed time in seconds in face detection dengan 100 gambar : 1.196296
# hasil total: 19.574484 detik
# hasil tambahfinal:  19.574484
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951072948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951072948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E739948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E739948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA33B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA33B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  87.2217424 86.0443509
# elapsed time in seconds in face detection dengan 100 gambar : 1.177391
# hasil total: 20.751875 detik
# hasil tambahfinal:  20.751875
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953F4798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953F4798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962970708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962970708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89508D1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89508D1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  88.1187882 87.2230703
# elapsed time in seconds in face detection dengan 100 gambar : 0.895718
# hasil total: 21.647593 detik
# hasil tambahfinal:  21.647593
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950613A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950613A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D8048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D8048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962970A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962970A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  89.016052 88.1200507
# elapsed time in seconds in face detection dengan 100 gambar : 0.896001
# hasil total: 22.543594 detik
# hasil tambahfinal:  22.543594
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89538F678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89538F678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B43A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B43A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576F8708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576F8708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  90.1755858 89.0176555
# elapsed time in seconds in face detection dengan 100 gambar : 1.157930
# hasil total: 23.701525 detik
# hasil tambahfinal:  23.701525
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962970678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962970678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA18B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA18B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F899D8> and will run it as-is.
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA4D3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA4D3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  168.6778501 167.7879948
# elapsed time in seconds in face detection dengan 100 gambar : 0.889855
# hasil total: 102.077598 detik
# hasil tambahfinal:  102.077598
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7614C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7614C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576EEA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576EEA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA71F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA71F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  169.7050023 168.6792643
# elapsed time in seconds in face detection dengan 100 gambar : 1.025738
# hasil total: 103.103336 detik
# hasil tambahfinal:  103.103336
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA71CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA71CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634DC0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634DC0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9469121F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9469121F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  170.7127793 169.7063218
# elapsed time in seconds in face detection dengan 100 gambar : 1.006457
# hasil total: 104.109794 detik
# hasil tambahfinal:  104.109794
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF7BAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF7BAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634DCF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634DCF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E771F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E771F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  171.9423737 170.7139663
# elapsed time in seconds in face detection dengan 100 gambar : 1.228407
# hasil total: 105.338201 detik
# hasil tambahfinal:  105.338201
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7CA948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7CA948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCA7558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCA7558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DF948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DF948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  172.8970256 171.9434428
# elapsed time in seconds in face detection dengan 100 gambar : 0.953583
# hasil total: 106.291784 detik
# hasil tambahfinal:  106.291784
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E771828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E771828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C42A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C42A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AD1798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AD1798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  173.8321623 172.8981493
# elapsed time in seconds in face detection dengan 100 gambar : 0.934013
# hasil total: 107.225797 detik
# hasil tambahfinal:  107.225797
# >loaded 4 examples for class: cadugd
# Time:  107.408447

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal2 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal2
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
		#t1_stop = process_time()
	stop = timeit.default_timer()
		
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal2 = tambahlagi1
		# for i in range(extract_face):
		# 	print('total 10x: ', sum(tambah))
		#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal2)
		
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/2/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C42A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C42A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEABF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEABF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BF828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BF828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  175.0882766 173.974162
# elapsed time in seconds in face detection dengan 100 gambar : 1.114115
# hasil total: 1.114115 detik
# hasil tambahfinal:  1.114115
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627A1EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627A1EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B85594C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B85594C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E58A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E58A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  176.0533637 175.0894279
# elapsed time in seconds in face detection dengan 100 gambar : 0.963936
# hasil total: 2.078050 detik
# hasil tambahfinal:  2.078050
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BFB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BFB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957708A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957708A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF77F048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF77F048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  177.0172903 176.0545536
# elapsed time in seconds in face detection dengan 100 gambar : 0.962737
# hasil total: 3.040787 detik
# hasil tambahfinal:  3.040787
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E58A678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E58A678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF8264C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF8264C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF735828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF735828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  178.0038104 177.0183639
# elapsed time in seconds in face detection dengan 100 gambar : 0.985446
# hasil total: 4.026234 detik
# hasil tambahfinal:  4.026234
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FD3168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FD3168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E873A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E873A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510B15E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510B15E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  178.9353917 178.0052938
# elapsed time in seconds in face detection dengan 100 gambar : 0.930098
# hasil total: 4.956332 detik
# hasil tambahfinal:  4.956332
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E87DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E87DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94697E708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94697E708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957747C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957747C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  179.7965735 178.9368169
# elapsed time in seconds in face detection dengan 100 gambar : 0.859757
# hasil total: 5.816088 detik
# hasil tambahfinal:  5.816088
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF0AD8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF0AD8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D6168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D6168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  180.8751254 179.7978752
# elapsed time in seconds in face detection dengan 100 gambar : 1.077250
# hasil total: 6.893338 detik
# hasil tambahfinal:  6.893338
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7D2798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7D2798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7D2A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7D2A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  181.7960001 180.8762933
# elapsed time in seconds in face detection dengan 100 gambar : 0.919707
# hasil total: 7.813045 detik
# hasil tambahfinal:  7.813045
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7D2828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7D2828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7830D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7830D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C401558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C401558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  182.7129575 181.7972616
# elapsed time in seconds in face detection dengan 100 gambar : 0.915696
# hasil total: 8.728741 detik
# hasil tambahfinal:  8.728741
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEEC1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEEC1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECC9948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECC9948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  183.6036734 182.7146184
# elapsed time in seconds in face detection dengan 100 gambar : 0.889055
# hasil total: 9.617796 detik
# hasil tambahfinal:  9.617796
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECC99D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECC99D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3F5708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3F5708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF720DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF720DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  184.5109888 183.6050679
# elapsed time in seconds in face detection dengan 100 gambar : 0.905921
# hasil total: 10.523717 detik
# hasil tambahfinal:  10.523717
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B993048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B993048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA009D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA009D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3F5798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3F5798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  185.4306825 184.5121882
# elapsed time in seconds in face detection dengan 100 gambar : 0.918494
# hasil total: 11.442211 detik
# hasil tambahfinal:  11.442211
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9C7558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9C7558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF770828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF770828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF22DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF22DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  186.3501592 185.431924
# elapsed time in seconds in face detection dengan 100 gambar : 0.918235
# hasil total: 12.360446 detik
# hasil tambahfinal:  12.360446
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F81D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F81D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCBDEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCBDEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7700D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7700D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  187.2440031 186.3512666
# elapsed time in seconds in face detection dengan 100 gambar : 0.892736
# hasil total: 13.253183 detik
# hasil tambahfinal:  13.253183
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FD3318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FD3318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950D9798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950D9798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634E63A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634E63A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  188.1829609 187.2452984
# elapsed time in seconds in face detection dengan 100 gambar : 0.937663
# hasil total: 14.190845 detik
# hasil tambahfinal:  14.190845
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F82558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F82558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA1F318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA1F318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F81B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F81B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  189.194936 188.1841967
# elapsed time in seconds in face detection dengan 100 gambar : 1.010739
# hasil total: 15.201585 detik
# hasil tambahfinal:  15.201585
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCBDDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E60B4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E60B4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  263.8406794 262.8485813
# elapsed time in seconds in face detection dengan 100 gambar : 0.992098
# hasil total: 89.706034 detik
# hasil tambahfinal:  89.706034
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696E0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696E0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B800DC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B800DC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953CC048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953CC048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  264.7113702 263.8417939
# elapsed time in seconds in face detection dengan 100 gambar : 0.869576
# hasil total: 90.575610 detik
# hasil tambahfinal:  90.575610
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696ECA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696ECA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EA24C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EA24C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3D30D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3D30D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  265.5549033 264.7128935
# elapsed time in seconds in face detection dengan 100 gambar : 0.842010
# hasil total: 91.417620 detik
# hasil tambahfinal:  91.417620
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3D39D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3D39D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF725C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF725C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505788B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505788B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  266.5694167 265.556204
# elapsed time in seconds in face detection dengan 100 gambar : 1.013213
# hasil total: 92.430833 detik
# hasil tambahfinal:  92.430833
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF725678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF725678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA0B9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA0B9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95106B8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95106B8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  267.526583 266.5705273
# elapsed time in seconds in face detection dengan 100 gambar : 0.956056
# hasil total: 93.386888 detik
# hasil tambahfinal:  93.386888
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF09708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF09708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42B288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42B288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42B168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42B168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  268.4302731 267.5276897
# elapsed time in seconds in face detection dengan 100 gambar : 0.902583
# hasil total: 94.289472 detik
# hasil tambahfinal:  94.289472
# >loaded 4 examples for class: cadugd
# Time:  94.46111869999999

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal3 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal3
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
		#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal3 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal3)
	
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/3/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F9C678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F9C678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9577510D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9577510D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  269.708049 268.5209312
# elapsed time in seconds in face detection dengan 100 gambar : 1.187118
# hasil total: 1.187118 detik
# hasil tambahfinal:  1.187118
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7C3168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7C3168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF725288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF725288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  270.6948274 269.709198
# elapsed time in seconds in face detection dengan 100 gambar : 0.985629
# hasil total: 2.172747 detik
# hasil tambahfinal:  2.172747
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF766B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF766B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF02828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF02828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF02798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF02798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  271.5543154 270.6961185
# elapsed time in seconds in face detection dengan 100 gambar : 0.858197
# hasil total: 3.030944 detik
# hasil tambahfinal:  3.030944
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF929D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF929D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576AF4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576AF4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C39E5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C39E5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  272.4098995 271.5557284
# elapsed time in seconds in face detection dengan 100 gambar : 0.854171
# hasil total: 3.885115 detik
# hasil tambahfinal:  3.885115
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9F3D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9F3D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6C288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6C288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6C168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6C168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  273.3267691 272.4114564
# elapsed time in seconds in face detection dengan 100 gambar : 0.915313
# hasil total: 4.800428 detik
# hasil tambahfinal:  4.800428
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC84828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC84828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96350E5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96350E5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B45E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B45E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  274.2502503 273.3278661
# elapsed time in seconds in face detection dengan 100 gambar : 0.922384
# hasil total: 5.722812 detik
# hasil tambahfinal:  5.722812
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6CAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7F6CAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD21F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD21F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  275.1614489 274.2513735
# elapsed time in seconds in face detection dengan 100 gambar : 0.910075
# hasil total: 6.632887 detik
# hasil tambahfinal:  6.632887
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953930D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953930D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF82FDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF82FDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95108D438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95108D438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  276.0483362 275.1625636
# elapsed time in seconds in face detection dengan 100 gambar : 0.885773
# hasil total: 7.518660 detik
# hasil tambahfinal:  7.518660
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94692A558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94692A558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5B51F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5B51F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5B5EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5B5EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  277.07288 276.0496353
# elapsed time in seconds in face detection dengan 100 gambar : 1.023245
# hasil total: 8.541905 detik
# hasil tambahfinal:  8.541905
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE7DE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE7DE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF74B288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF74B288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B45E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B45E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  278.0985873 277.0739752
# elapsed time in seconds in face detection dengan 100 gambar : 1.024612
# hasil total: 9.566517 detik
# hasil tambahfinal:  9.566517
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA14558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA14558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  278.9541573 278.0998998
# elapsed time in seconds in face detection dengan 100 gambar : 0.854258
# hasil total: 10.420774 detik
# hasil tambahfinal:  10.420774
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF0AD8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF0AD8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C2048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C2048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950818B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950818B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  279.8716408 278.9554325
# elapsed time in seconds in face detection dengan 100 gambar : 0.916208
# hasil total: 11.336983 detik
# hasil tambahfinal:  11.336983
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF6BB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF6BB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7B8D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7B8D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950BA828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950BA828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  280.8221772 279.8728925
# elapsed time in seconds in face detection dengan 100 gambar : 0.949285
# hasil total: 12.286267 detik
# hasil tambahfinal:  12.286267
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7B8DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7B8DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF751D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF751D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505E2288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505E2288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  281.7520544 280.8232854
# elapsed time in seconds in face detection dengan 100 gambar : 0.928769
# hasil total: 13.215036 detik
# hasil tambahfinal:  13.215036
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C404B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C404B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946952E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946952E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA114C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA114C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  282.7043671 281.7531078
# elapsed time in seconds in face detection dengan 100 gambar : 0.951259
# hasil total: 14.166296 detik
# hasil tambahfinal:  14.166296
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946952D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946952D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895412D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895412D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8954123A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8954123A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  283.6048611 282.7054382
# elapsed time in seconds in face detection dengan 100 gambar : 0.899423
# hasil total: 15.065719 detik
# hasil tambahfinal:  15.065719
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FDCEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E973A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E973A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  358.3706262 357.4824372
# elapsed time in seconds in face detection dengan 100 gambar : 0.888189
# hasil total: 89.734197 detik
# hasil tambahfinal:  89.734197
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576D0DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576D0DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF715E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF715E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3CA0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3CA0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  359.3212765 358.3721001
# elapsed time in seconds in face detection dengan 100 gambar : 0.949176
# hasil total: 90.683373 detik
# hasil tambahfinal:  90.683373
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634CA318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634CA318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCA9F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCA9F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DE438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DE438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  360.3823036 359.3225833
# elapsed time in seconds in face detection dengan 100 gambar : 1.059720
# hasil total: 91.743094 detik
# hasil tambahfinal:  91.743094
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634CA798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634CA798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B1438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B1438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634CAAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634CAAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  361.4102574 360.383504
# elapsed time in seconds in face detection dengan 100 gambar : 1.026753
# hasil total: 92.769847 detik
# hasil tambahfinal:  92.769847
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B13A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B13A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895098F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895098F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B995678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B995678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  362.3830241 361.4115609
# elapsed time in seconds in face detection dengan 100 gambar : 0.971463
# hasil total: 93.741310 detik
# hasil tambahfinal:  93.741310
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E774318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E774318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8567318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8567318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C4313A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C4313A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  363.370294 362.3842587
# elapsed time in seconds in face detection dengan 100 gambar : 0.986035
# hasil total: 94.727346 detik
# hasil tambahfinal:  94.727346
# >loaded 4 examples for class: cadugd
# Time:  94.85566879999999

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal4 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal4
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
		#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal4 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal4)
	
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/4/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF19E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF19E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  364.3417346 363.4642434
# elapsed time in seconds in face detection dengan 100 gambar : 0.877491
# hasil total: 0.877491 detik
# hasil tambahfinal:  0.877491
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89540C168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89540C168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96353D948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96353D948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3A5438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3A5438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  365.2012962 364.3428171
# elapsed time in seconds in face detection dengan 100 gambar : 0.858479
# hasil total: 1.735970 detik
# hasil tambahfinal:  1.735970
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89540C558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89540C558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFABB4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFABB4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E8A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E8A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  366.1952768 365.2028129
# elapsed time in seconds in face detection dengan 100 gambar : 0.992464
# hasil total: 2.728434 detik
# hasil tambahfinal:  2.728434
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E909D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E909D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946956948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946956948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E71DEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E71DEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  367.3279734 366.1964989
# elapsed time in seconds in face detection dengan 100 gambar : 1.131475
# hasil total: 3.859909 detik
# hasil tambahfinal:  3.859909
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E90A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E90A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E738678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E738678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E602318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E602318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  368.2114631 367.3293288
# elapsed time in seconds in face detection dengan 100 gambar : 0.882134
# hasil total: 4.742043 detik
# hasil tambahfinal:  4.742043
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7380D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7380D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE97CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE97CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE97AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE97AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  369.0655301 368.2127647
# elapsed time in seconds in face detection dengan 100 gambar : 0.852765
# hasil total: 5.594808 detik
# hasil tambahfinal:  5.594808
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E831F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E831F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE979D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE979D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C40A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C40A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  370.0580137 369.0669165
# elapsed time in seconds in face detection dengan 100 gambar : 0.991097
# hasil total: 6.585906 detik
# hasil tambahfinal:  6.585906
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E738318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E738318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96353C5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96353C5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696B4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696B4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  370.9536174 370.0591149
# elapsed time in seconds in face detection dengan 100 gambar : 0.894502
# hasil total: 7.480408 detik
# hasil tambahfinal:  7.480408
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B73A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B73A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEDAF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEDAF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA093A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA093A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  371.9134642 370.9550464
# elapsed time in seconds in face detection dengan 100 gambar : 0.958418
# hasil total: 8.438826 detik
# hasil tambahfinal:  8.438826
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696B3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94696B3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953F0678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953F0678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953F0AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953F0AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  372.8427816 371.9145407
# elapsed time in seconds in face detection dengan 100 gambar : 0.928241
# hasil total: 9.367067 detik
# hasil tambahfinal:  9.367067
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89509CD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89509CD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9A9EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9A9EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FAD708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FAD708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  373.780776 372.8439083
# elapsed time in seconds in face detection dengan 100 gambar : 0.936868
# hasil total: 10.303935 detik
# hasil tambahfinal:  10.303935
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94693C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94693C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3CA678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3CA678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3CA438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3CA438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  374.6911846 373.781952
# elapsed time in seconds in face detection dengan 100 gambar : 0.909233
# hasil total: 11.213167 detik
# hasil tambahfinal:  11.213167
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF015DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF015DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  375.7267443 374.6923965
# elapsed time in seconds in face detection dengan 100 gambar : 1.034348
# hasil total: 12.247515 detik
# hasil tambahfinal:  12.247515
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9A9D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9A9D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7B6F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7B6F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  376.7416936 375.7280577
# elapsed time in seconds in face detection dengan 100 gambar : 1.013636
# hasil total: 13.261151 detik
# hasil tambahfinal:  13.261151
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C5828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C5828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5EB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5EB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA7AD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA7AD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  377.5889019 376.7427975
# elapsed time in seconds in face detection dengan 100 gambar : 0.846104
# hasil total: 14.107255 detik
# hasil tambahfinal:  14.107255
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C50D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C50D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC580D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC580D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E750A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E750A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  378.4356632 377.5903355
# elapsed time in seconds in face detection dengan 100 gambar : 0.845328
# hasil total: 14.952583 detik
# hasil tambahfinal:  14.952583
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895058678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C397438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C397438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  453.0095081 452.154982
# elapsed time in seconds in face detection dengan 100 gambar : 0.854526
# hasil total: 89.409071 detik
# hasil tambahfinal:  89.409071
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946927B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946927B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE8CDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE8CDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468DC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468DC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  453.9743206 453.0106387
# elapsed time in seconds in face detection dengan 100 gambar : 0.963682
# hasil total: 90.372753 detik
# hasil tambahfinal:  90.372753
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE8C798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE8C798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E64CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E64CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF253438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF253438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  455.1220507 453.9758882
# elapsed time in seconds in face detection dengan 100 gambar : 1.146163
# hasil total: 91.518916 detik
# hasil tambahfinal:  91.518916
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE8C708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE8C708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E85F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E85F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  456.1482826 455.1232031
# elapsed time in seconds in face detection dengan 100 gambar : 1.025080
# hasil total: 92.543995 detik
# hasil tambahfinal:  92.543995
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C397438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C397438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468DC798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468DC798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  457.0432234 456.1495611
# elapsed time in seconds in face detection dengan 100 gambar : 0.893662
# hasil total: 93.437657 detik
# hasil tambahfinal:  93.437657
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95770B048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95770B048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634ACD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634ACD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E736798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E736798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  457.8980247 457.0444394
# elapsed time in seconds in face detection dengan 100 gambar : 0.853585
# hasil total: 94.291243 detik
# hasil tambahfinal:  94.291243
# >loaded 4 examples for class: cadugd
# Time:  94.43916039999999

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal5 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal5
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal5 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal5)
	
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/5/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468DC438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468DC438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E71EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E71EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953BC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953BC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  459.2454148 458.1122845
# elapsed time in seconds in face detection dengan 100 gambar : 1.133130
# hasil total: 1.133130 detik
# hasil tambahfinal:  1.133130
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E71828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E71828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95772BCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95772BCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895064B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895064B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  460.0806795 459.2467163
# elapsed time in seconds in face detection dengan 100 gambar : 0.833963
# hasil total: 1.967093 detik
# hasil tambahfinal:  1.967093
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E92558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E92558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C408DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C408DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895401168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895401168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  460.9040358 460.0819866
# elapsed time in seconds in face detection dengan 100 gambar : 0.822049
# hasil total: 2.789143 detik
# hasil tambahfinal:  2.789143
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950FBB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950FBB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF45CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF45CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF45A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF45A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  461.856248 460.905272
# elapsed time in seconds in face detection dengan 100 gambar : 0.950976
# hasil total: 3.740119 detik
# hasil tambahfinal:  3.740119
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF45168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF45168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA3ADC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA3ADC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962946168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962946168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  462.7826779 461.8579348
# elapsed time in seconds in face detection dengan 100 gambar : 0.924743
# hasil total: 4.664862 detik
# hasil tambahfinal:  4.664862
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA3A708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA3A708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF16CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF16CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5CAB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5CAB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  463.7036977 462.7837912
# elapsed time in seconds in face detection dengan 100 gambar : 0.919907
# hasil total: 5.584768 detik
# hasil tambahfinal:  5.584768
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576BA4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576BA4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D91F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D91F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  464.7557037 463.7047783
# elapsed time in seconds in face detection dengan 100 gambar : 1.050925
# hasil total: 6.635694 detik
# hasil tambahfinal:  6.635694
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DBDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DBDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E86F1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E86F1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505B5E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505B5E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  465.6169169 464.7570025
# elapsed time in seconds in face detection dengan 100 gambar : 0.859914
# hasil total: 7.495608 detik
# hasil tambahfinal:  7.495608
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9B3438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9B3438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505898B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505898B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E567E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E567E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  466.6088283 465.6183692
# elapsed time in seconds in face detection dengan 100 gambar : 0.990459
# hasil total: 8.486067 detik
# hasil tambahfinal:  8.486067
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505B5CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505B5CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B853E048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B853E048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505B5708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505B5708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  467.4395812 466.6099331
# elapsed time in seconds in face detection dengan 100 gambar : 0.829648
# hasil total: 9.315715 detik
# hasil tambahfinal:  9.315715
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B853EEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B853EEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC60048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC60048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DED84C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DED84C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  468.2748794 467.4408644
# elapsed time in seconds in face detection dengan 100 gambar : 0.834015
# hasil total: 10.149730 detik
# hasil tambahfinal:  10.149730
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECAAC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECAAC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECAAF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECAAF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89540F1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89540F1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  469.1659238 468.2766156
# elapsed time in seconds in face detection dengan 100 gambar : 0.889308
# hasil total: 11.039038 detik
# hasil tambahfinal:  11.039038
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FDE288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FDE288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953EE048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953EE048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF776168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF776168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  470.125097 469.1672161
# elapsed time in seconds in face detection dengan 100 gambar : 0.957881
# hasil total: 11.996919 detik
# hasil tambahfinal:  11.996919
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FDE318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FDE318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF80D3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF80D3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FA49D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FA49D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  471.0482793 470.1261754
# elapsed time in seconds in face detection dengan 100 gambar : 0.922104
# hasil total: 12.919023 detik
# hasil tambahfinal:  12.919023
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B8828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953B8828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E7D678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E7D678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96354FC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96354FC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  471.9519891 471.0493411
# elapsed time in seconds in face detection dengan 100 gambar : 0.902648
# hasil total: 13.821671 detik
# hasil tambahfinal:  13.821671
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950444C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950444C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF87288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF87288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  473.0202486 471.9530819
# elapsed time in seconds in face detection dengan 100 gambar : 1.067167
# hasil total: 14.888838 detik
# hasil tambahfinal:  14.888838
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF87DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946933828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946933828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  547.5117249 546.5693516
# elapsed time in seconds in face detection dengan 100 gambar : 0.942373
# hasil total: 89.280324 detik
# hasil tambahfinal:  89.280324
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E760F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E760F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FB13A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FB13A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96357B798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96357B798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  548.4574051 547.5128214
# elapsed time in seconds in face detection dengan 100 gambar : 0.944584
# hasil total: 90.224907 detik
# hasil tambahfinal:  90.224907
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627BD828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627BD828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5EAB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5EAB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895098318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895098318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  549.4180495 548.4587045
# elapsed time in seconds in face detection dengan 100 gambar : 0.959345
# hasil total: 91.184252 detik
# hasil tambahfinal:  91.184252
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF44BDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF44BDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA8D9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA8D9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505AD1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505AD1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  550.3966556 549.4191412
# elapsed time in seconds in face detection dengan 100 gambar : 0.977514
# hasil total: 92.161767 detik
# hasil tambahfinal:  92.161767
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953E5E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953E5E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634AAB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634AAB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634AA318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634AA318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  551.2601462 550.3979237
# elapsed time in seconds in face detection dengan 100 gambar : 0.862223
# hasil total: 93.023989 detik
# hasil tambahfinal:  93.023989
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4B79D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4B79D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4B78B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4B78B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FBE3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FBE3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  552.1467654 551.2612355
# elapsed time in seconds in face detection dengan 100 gambar : 0.885530
# hasil total: 93.909519 detik
# hasil tambahfinal:  93.909519
# >loaded 4 examples for class: cadugd
# Time:  94.039019

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal6 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal6
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
		#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal6 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal6)
	
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/6/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF761828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF761828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895427EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895427EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E557C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E557C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  553.2566321 552.2429662
# elapsed time in seconds in face detection dengan 100 gambar : 1.013666
# hasil total: 1.013666 detik
# hasil tambahfinal:  1.013666
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FBE288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FBE288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  554.290487 553.2579057
# elapsed time in seconds in face detection dengan 100 gambar : 1.032581
# hasil total: 2.046247 detik
# hasil tambahfinal:  2.046247
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8954273A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8954273A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  555.1184794 554.2918051
# elapsed time in seconds in face detection dengan 100 gambar : 0.826674
# hasil total: 2.872921 detik
# hasil tambahfinal:  2.872921
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E737B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E737B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  556.1387674 555.1198107
# elapsed time in seconds in face detection dengan 100 gambar : 1.018957
# hasil total: 3.891878 detik
# hasil tambahfinal:  3.891878
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963496EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963496EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94691E3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94691E3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  557.1329561 556.1401822
# elapsed time in seconds in face detection dengan 100 gambar : 0.992774
# hasil total: 4.884652 detik
# hasil tambahfinal:  4.884652
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FD2C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510DDAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510DDAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFFBBDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFFBBDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  557.9773686 557.1341286
# elapsed time in seconds in face detection dengan 100 gambar : 0.843240
# hasil total: 5.727892 detik
# hasil tambahfinal:  5.727892
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895395EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895395EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962963828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962963828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4ADC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4ADC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  558.8318722 557.9789407
# elapsed time in seconds in face detection dengan 100 gambar : 0.852932
# hasil total: 6.580824 detik
# hasil tambahfinal:  6.580824
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895395B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895395B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510DDCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510DDCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505DFD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505DFD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  559.7238845 558.8334177
# elapsed time in seconds in face detection dengan 100 gambar : 0.890467
# hasil total: 7.471290 detik
# hasil tambahfinal:  7.471290
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4CCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4CCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957703828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957703828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8544318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8544318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  560.6544837 559.725207
# elapsed time in seconds in face detection dengan 100 gambar : 0.929277
# hasil total: 8.400567 detik
# hasil tambahfinal:  8.400567
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C384678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C384678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DED5558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DED5558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FBB0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FBB0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  561.6469407 560.6556089
# elapsed time in seconds in face detection dengan 100 gambar : 0.991332
# hasil total: 9.391899 detik
# hasil tambahfinal:  9.391899
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C3288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C3288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963528AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963528AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FBB8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FBB8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  562.8936269 561.6480732
# elapsed time in seconds in face detection dengan 100 gambar : 1.245554
# hasil total: 10.637453 detik
# hasil tambahfinal:  10.637453
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FBB3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FBB3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DED5948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DED5948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4C0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4C0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  563.7203145 562.8947063
# elapsed time in seconds in face detection dengan 100 gambar : 0.825608
# hasil total: 11.463061 detik
# hasil tambahfinal:  11.463061
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF4C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  564.5468962 563.7218115
# elapsed time in seconds in face detection dengan 100 gambar : 0.825085
# hasil total: 12.288145 detik
# hasil tambahfinal:  12.288145
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F91DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F91DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89EC991F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89EC991F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  565.4031699 564.548177
# elapsed time in seconds in face detection dengan 100 gambar : 0.854993
# hasil total: 13.143138 detik
# hasil tambahfinal:  13.143138
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510598B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510598B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957747C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957747C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  566.4190473 565.4043401
# elapsed time in seconds in face detection dengan 100 gambar : 1.014707
# hasil total: 14.157846 detik
# hasil tambahfinal:  14.157846
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC60F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC60F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF43E558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF43E558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAAD9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAAD9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  567.2486036 566.4201616
# elapsed time in seconds in face detection dengan 100 gambar : 0.828442
# hasil total: 14.986288 detik
# hasil tambahfinal:  14.986288
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95775F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC74828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC74828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  641.1541839 640.1955336
# elapsed time in seconds in face detection dengan 100 gambar : 0.958650
# hasil total: 88.780282 detik
# hasil tambahfinal:  88.780282
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E55CC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E55CC18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E553798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E553798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951059CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951059CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  642.418091 641.1553003
# elapsed time in seconds in face detection dengan 100 gambar : 1.262791
# hasil total: 90.043073 detik
# hasil tambahfinal:  90.043073
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510A4B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510A4B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510A4678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510A4678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  643.3165794 642.4193685
# elapsed time in seconds in face detection dengan 100 gambar : 0.897211
# hasil total: 90.940284 detik
# hasil tambahfinal:  90.940284
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA825E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA825E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89538D8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89538D8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAEE4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAEE4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  644.1669651 643.317672
# elapsed time in seconds in face detection dengan 100 gambar : 0.849293
# hasil total: 91.789577 detik
# hasil tambahfinal:  91.789577
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8005CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8005CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963588D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963588D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FE6288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FE6288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  645.1418311 644.1680624
# elapsed time in seconds in face detection dengan 100 gambar : 0.973769
# hasil total: 92.763345 detik
# hasil tambahfinal:  92.763345
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC74168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC74168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A53A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A53A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAEE708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAEE708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  646.0975444 645.1429447
# elapsed time in seconds in face detection dengan 100 gambar : 0.954600
# hasil total: 93.717945 detik
# hasil tambahfinal:  93.717945
# >loaded 4 examples for class: cadugd
# Time:  93.8629568

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal7 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal7
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal7 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal7)
	
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/7/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CEE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CEE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA81F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA81F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA81E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA81E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  647.2289343 646.2233881
# elapsed time in seconds in face detection dengan 100 gambar : 1.005546
# hasil total: 1.005546 detik
# hasil tambahfinal:  1.005546
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA81D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA81D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF9FB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF9FB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECC13A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89ECC13A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  648.0829838 647.2305303
# elapsed time in seconds in face detection dengan 100 gambar : 0.852453
# hasil total: 1.858000 detik
# hasil tambahfinal:  1.858000
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A5948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A5948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950ABF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950ABF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950AB558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950AB558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  648.9402206 648.0841705
# elapsed time in seconds in face detection dengan 100 gambar : 0.856050
# hasil total: 2.714050 detik
# hasil tambahfinal:  2.714050
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950ABE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950ABE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D2CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D2CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42F3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42F3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  649.9539836 648.941312
# elapsed time in seconds in face detection dengan 100 gambar : 1.012672
# hasil total: 3.726721 detik
# hasil tambahfinal:  3.726721
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856B8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856B8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E45F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E45F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96AB6B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96AB6B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  651.2860744 649.9553179
# elapsed time in seconds in face detection dengan 100 gambar : 1.330757
# hasil total: 5.057478 detik
# hasil tambahfinal:  5.057478
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950AB4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950AB4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962948708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962948708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  652.3427945 651.2873395
# elapsed time in seconds in face detection dengan 100 gambar : 1.055455
# hasil total: 6.112933 detik
# hasil tambahfinal:  6.112933
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D20D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D20D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A5438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A5438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  653.3019693 652.3437996
# elapsed time in seconds in face detection dengan 100 gambar : 0.958170
# hasil total: 7.071103 detik
# hasil tambahfinal:  7.071103
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634ACDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634ACDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E45048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E45048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7205E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7205E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  654.2757193 653.3029681
# elapsed time in seconds in face detection dengan 100 gambar : 0.972751
# hasil total: 8.043854 detik
# hasil tambahfinal:  8.043854
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7383A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7383A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856B3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856B3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCB88B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFCB88B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  655.281295 654.2769766
# elapsed time in seconds in face detection dengan 100 gambar : 1.004318
# hasil total: 9.048172 detik
# hasil tambahfinal:  9.048172
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF42F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627D3AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627D3AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEB5168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEB5168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  656.2809702 655.282371
# elapsed time in seconds in face detection dengan 100 gambar : 0.998599
# hasil total: 10.046771 detik
# hasil tambahfinal:  10.046771
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE85EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE85EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A4F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A4F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951040168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951040168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  657.1623831 656.2821271
# elapsed time in seconds in face detection dengan 100 gambar : 0.880256
# hasil total: 10.927027 detik
# hasil tambahfinal:  10.927027
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E93DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E93DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89EC98AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89EC98AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89EC98288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89EC98288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  658.0380197 657.1635017
# elapsed time in seconds in face detection dengan 100 gambar : 0.874518
# hasil total: 11.801545 detik
# hasil tambahfinal:  11.801545
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF0E948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF0E948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634B08B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634B08B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E58E318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E58E318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  658.9979082 658.0392927
# elapsed time in seconds in face detection dengan 100 gambar : 0.958615
# hasil total: 12.760161 detik
# hasil tambahfinal:  12.760161
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297CF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297CF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FDEF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FDEF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FDEA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B7FDEA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  659.9790729 658.9989917
# elapsed time in seconds in face detection dengan 100 gambar : 0.980081
# hasil total: 13.740242 detik
# hasil tambahfinal:  13.740242
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3AC0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3AC0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3ACE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3ACE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634ACEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634ACEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  661.1913098 659.9802133
# elapsed time in seconds in face detection dengan 100 gambar : 1.211097
# hasil total: 14.951339 detik
# hasil tambahfinal:  14.951339
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF25CCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF25CCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A5288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8953A5288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962948948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962948948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  662.1478931 661.192426
# elapsed time in seconds in face detection dengan 100 gambar : 0.955467
# hasil total: 15.906806 detik
# hasil tambahfinal:  15.906806
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7C94C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7C94C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  738.6575341 737.6944054
# elapsed time in seconds in face detection dengan 100 gambar : 0.963129
# hasil total: 92.298945 detik
# hasil tambahfinal:  92.298945
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505A4EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505A4EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF417168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF417168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  739.6209047 738.6586482
# elapsed time in seconds in face detection dengan 100 gambar : 0.962256
# hasil total: 93.261201 detik
# hasil tambahfinal:  93.261201
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D8708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505D8708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE72D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE72D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  740.5534067 739.6223582
# elapsed time in seconds in face detection dengan 100 gambar : 0.931048
# hasil total: 94.192250 detik
# hasil tambahfinal:  94.192250
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96358D798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96358D798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634E28B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634E28B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  741.6222393 740.5545368
# elapsed time in seconds in face detection dengan 100 gambar : 1.067702
# hasil total: 95.259952 detik
# hasil tambahfinal:  95.259952
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F5288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F5288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E505E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E505E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF25CB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF25CB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  742.7347388 741.6235794
# elapsed time in seconds in face detection dengan 100 gambar : 1.111159
# hasil total: 96.371112 detik
# hasil tambahfinal:  96.371112
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF199D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF199D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F895E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F895E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  743.727632 742.7359099
# elapsed time in seconds in face detection dengan 100 gambar : 0.991722
# hasil total: 97.362834 detik
# hasil tambahfinal:  97.362834
# >loaded 4 examples for class: cadugd
# Time:  97.52856439999994

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal8 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal8
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal8 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal8)
	
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/8/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF19288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF19288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7515E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7515E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  744.7982348 743.8047913
# elapsed time in seconds in face detection dengan 100 gambar : 0.993444
# hasil total: 0.993444 detik
# hasil tambahfinal:  0.993444
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFFA0708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFFA0708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFFA0E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFFA0E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  745.6890237 744.7994736
# elapsed time in seconds in face detection dengan 100 gambar : 0.889550
# hasil total: 1.882994 detik
# hasil tambahfinal:  1.882994
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B944AB3E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505BC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505BC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895388948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895388948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  746.5544205 745.6901244
# elapsed time in seconds in face detection dengan 100 gambar : 0.864296
# hasil total: 2.747290 detik
# hasil tambahfinal:  2.747290
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3A7F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3A7F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856F5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B856F5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4978B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4978B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  747.6166354 746.5557885
# elapsed time in seconds in face detection dengan 100 gambar : 1.060847
# hasil total: 3.808137 detik
# hasil tambahfinal:  3.808137
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF71318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF71318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF497B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF497B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B990948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B990948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  748.4612877 747.6179588
# elapsed time in seconds in face detection dengan 100 gambar : 0.843329
# hasil total: 4.651465 detik
# hasil tambahfinal:  4.651465
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89542AEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89542AEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7745E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7745E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7CC4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7CC4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  749.3205859 748.4629234
# elapsed time in seconds in face detection dengan 100 gambar : 0.857662
# hasil total: 5.509128 detik
# hasil tambahfinal:  5.509128
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA7ACA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA7ACA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96297C678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C413948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C413948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  750.1920081 749.3218963
# elapsed time in seconds in face detection dengan 100 gambar : 0.870112
# hasil total: 6.379240 detik
# hasil tambahfinal:  6.379240
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DD2CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DD2CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576D35E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576D35E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BE4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BE4C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  751.1175656 750.1932754
# elapsed time in seconds in face detection dengan 100 gambar : 0.924290
# hasil total: 7.303530 detik
# hasil tambahfinal:  7.303530
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC87828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC87828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F1048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F1048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895388048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895388048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  752.3382685 751.1188643
# elapsed time in seconds in face detection dengan 100 gambar : 1.219404
# hasil total: 8.522934 detik
# hasil tambahfinal:  8.522934
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7CCB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7CCB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F890D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F890D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FCA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  753.2959621 752.3395946
# elapsed time in seconds in face detection dengan 100 gambar : 0.956367
# hasil total: 9.479302 detik
# hasil tambahfinal:  9.479302
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CE288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CE288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F5558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F5558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962948318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962948318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  754.3266179 753.2973377
# elapsed time in seconds in face detection dengan 100 gambar : 1.029280
# hasil total: 10.508582 detik
# hasil tambahfinal:  10.508582
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E50948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E50948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F7BB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F7BB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E38828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E38828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  755.2079157 754.3277073
# elapsed time in seconds in face detection dengan 100 gambar : 0.880208
# hasil total: 11.388790 detik
# hasil tambahfinal:  11.388790
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7CA3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7CA3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B853C678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B853C678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510E0D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510E0D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  756.0769185 755.2091527
# elapsed time in seconds in face detection dengan 100 gambar : 0.867766
# hasil total: 12.256556 detik
# hasil tambahfinal:  12.256556
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F7BD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F7BD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510C4798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510C4798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E9A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E9A8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  757.071101 756.0782759
# elapsed time in seconds in face detection dengan 100 gambar : 0.992825
# hasil total: 13.249381 detik
# hasil tambahfinal:  13.249381
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E9A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E9A948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF27678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF27678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946931D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B946931D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  758.0283861 757.0722399
# elapsed time in seconds in face detection dengan 100 gambar : 0.956146
# hasil total: 14.205527 detik
# hasil tambahfinal:  14.205527
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF65318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF65318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA14438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA14438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEBC1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DEBC1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  758.9657862 758.0294714
# elapsed time in seconds in face detection dengan 100 gambar : 0.936315
# hasil total: 15.141842 detik
# hasil tambahfinal:  15.141842
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA14A68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  834.1735047 833.2714317
# elapsed time in seconds in face detection dengan 100 gambar : 0.902073
# hasil total: 90.252001 detik
# hasil tambahfinal:  90.252001
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFACEDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFACEDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7ED5678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7ED5678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC5D318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFC5D318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  835.1110337 834.1746013
# elapsed time in seconds in face detection dengan 100 gambar : 0.936432
# hasil total: 91.188434 detik
# hasil tambahfinal:  91.188434
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA16C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95BA16C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F1B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F1B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D94C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D94C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  836.0216641 835.1123104
# elapsed time in seconds in face detection dengan 100 gambar : 0.909354
# hasil total: 92.097787 detik
# hasil tambahfinal:  92.097787
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F1CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F1CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B4CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9627B4CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8954223A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8954223A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  837.0619265 836.0227651
# elapsed time in seconds in face detection dengan 100 gambar : 1.039161
# hasil total: 93.136949 detik
# hasil tambahfinal:  93.136949
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F5DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F5DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F5AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634F5AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950A3F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950A3F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  837.9183562 837.0630324
# elapsed time in seconds in face detection dengan 100 gambar : 0.855324
# hasil total: 93.992273 detik
# hasil tambahfinal:  93.992273
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96356B438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96356B438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95104D798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95104D798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95104DDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95104DDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  838.811529 837.9196349
# elapsed time in seconds in face detection dengan 100 gambar : 0.891894
# hasil total: 94.884167 detik
# hasil tambahfinal:  94.884167
# >loaded 4 examples for class: cadugd
# Time:  95.01323560000003

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal9 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal9
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal9 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal9)
	
	return face_array
		
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/9/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95057C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95057C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E4ACA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E4ACA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957705168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B957705168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  839.9726078 838.9042136
# elapsed time in seconds in face detection dengan 100 gambar : 1.068394
# hasil total: 1.068394 detik
# hasil tambahfinal:  1.068394
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95107C798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95107C798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96AB68708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96AB68708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95107CA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95107CA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  840.8388985 839.9738978
# elapsed time in seconds in face detection dengan 100 gambar : 0.865001
# hasil total: 1.933395 detik
# hasil tambahfinal:  1.933395
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623E1DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623E1DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  841.9080168 840.8407338
# elapsed time in seconds in face detection dengan 100 gambar : 1.067283
# hasil total: 3.000678 detik
# hasil tambahfinal:  3.000678
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623E1F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623E1F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623E1AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623E1AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA82168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  842.8832749 841.9094771
# elapsed time in seconds in face detection dengan 100 gambar : 0.973798
# hasil total: 3.974476 detik
# hasil tambahfinal:  3.974476
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E4ADC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E4ADC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B950571F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B950571F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96AB68CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96AB68CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  843.8583068 842.8844863
# elapsed time in seconds in face detection dengan 100 gambar : 0.973820
# hasil total: 4.948296 detik
# hasil tambahfinal:  4.948296
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E43CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E43CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95772D708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95772D708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9E0DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9E0DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  844.6871351 843.8594064
# elapsed time in seconds in face detection dengan 100 gambar : 0.827729
# hasil total: 5.776025 detik
# hasil tambahfinal:  5.776025
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E43288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E43288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510915E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510915E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95772D798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95772D798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  845.5166493 844.6885881
# elapsed time in seconds in face detection dengan 100 gambar : 0.828061
# hasil total: 6.604086 detik
# hasil tambahfinal:  6.604086
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951091E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951091E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE74B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DE74B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF46678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF46678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  846.3772061 845.5179892
# elapsed time in seconds in face detection dengan 100 gambar : 0.859217
# hasil total: 7.463303 detik
# hasil tambahfinal:  7.463303
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7E8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7E8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7E8E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7E8E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DD50D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DD50D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  847.4455579 846.3786484
# elapsed time in seconds in face detection dengan 100 gambar : 1.066910
# hasil total: 8.530213 detik
# hasil tambahfinal:  8.530213
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DD55E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DD55E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468D9B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468D9B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468D9798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468D9798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  848.3090598 847.4469091
# elapsed time in seconds in face detection dengan 100 gambar : 0.862151
# hasil total: 9.392363 detik
# hasil tambahfinal:  9.392363
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468D98B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468D98B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895058948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B895058948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41B828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41B828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  849.1621715 848.3101403
# elapsed time in seconds in face detection dengan 100 gambar : 0.852031
# hasil total: 10.244394 detik
# hasil tambahfinal:  10.244394
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7ED5D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7ED5D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41BAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41BAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41B9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41B9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  850.2532823 849.163232
# elapsed time in seconds in face detection dengan 100 gambar : 1.090050
# hasil total: 11.334445 detik
# hasil tambahfinal:  11.334445
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89538F1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89538F1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95057C708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95057C708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FDB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FDB678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  851.2112724 850.2545512
# elapsed time in seconds in face detection dengan 100 gambar : 0.956721
# hasil total: 12.291166 detik
# hasil tambahfinal:  12.291166
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41B1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C41B1F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7E8048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7E8048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BECA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BECA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  852.1486515 851.2123758
# elapsed time in seconds in face detection dengan 100 gambar : 0.936276
# hasil total: 13.227442 detik
# hasil tambahfinal:  13.227442
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773F5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CED38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CED38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F53A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F53A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  853.0457445 852.1497982
# elapsed time in seconds in face detection dengan 100 gambar : 0.895946
# hasil total: 14.123388 detik
# hasil tambahfinal:  14.123388
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BE5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5BE5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634DB288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634DB288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA825E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFA825E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  854.0434846 853.0469312
# elapsed time in seconds in face detection dengan 100 gambar : 0.996553
# hasil total: 15.119941 detik
# hasil tambahfinal:  15.119941
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634DB048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E89318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E89318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  927.8278591 926.8836868
# elapsed time in seconds in face detection dengan 100 gambar : 0.944172
# hasil total: 88.804307 detik
# hasil tambahfinal:  88.804307
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F34C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9623F34C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E89F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E89F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DC40D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DC40D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  928.830125 927.8289296
# elapsed time in seconds in face detection dengan 100 gambar : 1.001195
# hasil total: 89.805503 detik
# hasil tambahfinal:  89.805503
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7ED8D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7ED8D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1C8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1C3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1C3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  929.9464466 928.8315342
# elapsed time in seconds in face detection dengan 100 gambar : 1.114912
# hasil total: 90.920415 detik
# hasil tambahfinal:  90.920415
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DC4EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964DC4EE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CED38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CED38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7DB708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  930.9613203 929.9477225
# elapsed time in seconds in face detection dengan 100 gambar : 1.013598
# hasil total: 91.934013 detik
# hasil tambahfinal:  91.934013
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1CA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94DF1CA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CEAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CEAF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  931.8466565 930.9627027
# elapsed time in seconds in face detection dengan 100 gambar : 0.883954
# hasil total: 92.817967 detik
# hasil tambahfinal:  92.817967
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E893A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E893A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EDCE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EDCE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  932.7190599 931.8478783
# elapsed time in seconds in face detection dengan 100 gambar : 0.871182
# hasil total: 93.689148 detik
# hasil tambahfinal:  93.689148
# >loaded 4 examples for class: cadugd
# Time:  93.81982949999997

# %%
# face detection for the 5 Celebrity Faces Dataset
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from terran.io import open_image
from terran.vis import display_image, vis_faces
from terran.face import face_detection
from time import process_time
import timeit
# configuration = tf.compat.v1.ConfigProto()
# configuration.gpu_options.allow_growth = True
# session = tf.compat.v1.Session(config=configuration)
# extract a single face from a given photograph
#160, 160
from timeit import default_timer as timer

start = timer()
tambahlagi1 = 0
tambahfinal10 = 0
def extract_face(filename, required_size=(160, 160)): #face net 160 x 160 /arc face 112 x 112
	global tambahlagi1
	global tambahfinal10
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	start = timeit.default_timer()
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	#t1_stop = process_time()
	#t1_stop = process_time()
	stop = timeit.default_timer()
	
	print('elapsed time: ', stop,start)
	tambah = stop-start
	print('elapsed time in seconds in face detection dengan 100 gambar : %f' % (tambah))

	tambahlagi1 = tambahlagi1 + tambah
	tambahfinal10 = tambahlagi1
	# for i in range(extract_face):
	# 	print('total 10x: ', sum(tambah))
	#tambahlagi= sum(tambah,tambahlagi)
	print('hasil total: %.6f detik' %tambahlagi1)
	print('hasil tambahfinal:  %.6f' % tambahfinal10)
	
	return face_array
	
		
	

# load images and extract faces for all images in a directory
def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		#print(path)
		# get face

		face = extract_face(path)
		#print('problem check 2')
		if(len(face) == 0):
			continue
		# store
		faces.append(face)
		#print('problem check 3')
	return faces

# load a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
	X, y = list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + subdir + '/'
		#print(subdir)
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		#print('problem check 4')
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		X.extend(faces)
		y.extend(labels)
		#print('problem check 5')
	return asarray(X), asarray(y)

# load train dataset
#detector = MTCNN()

#trainX, trainy = load_dataset('dataset/Hasil Split/train/')
#print(trainX.shape, trainy.shape)
# load test dataset
#testX, testy = load_dataset('dataset/Hasil Split/test/')

timeX,timey= load_dataset('dataset/testkecepatanfaces96/10/')
#valX, valy = load_dataset("dataset/result/val/")
# save arrays to one file in compressed format

#savez_compressed('facenet+RetinaFace+kecepatan.npz', timeX, timey) #valX, valy) # npz model 
print('Time: ', timer()-start)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F894C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F894C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7B9708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B88E7B9708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510630D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9510630D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  933.8213808 932.8395148
# elapsed time in seconds in face detection dengan 100 gambar : 0.981866
# hasil total: 0.981866 detik
# hasil tambahfinal:  0.981866
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5DD8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5DD8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E14B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E14B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E14558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B964E14558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  934.7105968 933.8225076
# elapsed time in seconds in face detection dengan 100 gambar : 0.888089
# hasil total: 1.869955 detik
# hasil tambahfinal:  1.869955
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950EC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950EC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B85513A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B85513A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DA0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DA0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  935.7233214 934.7117992
# elapsed time in seconds in face detection dengan 100 gambar : 1.011522
# hasil total: 2.881477 detik
# hasil tambahfinal:  2.881477
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8564798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8B8564798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96ABA2B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96ABA2B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96ABA2438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96ABA2438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  936.5714526 935.7245335
# elapsed time in seconds in face detection dengan 100 gambar : 0.846919
# hasil total: 3.728397 detik
# hasil tambahfinal:  3.728397
# >loaded 4 examples for class: adhast
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DA5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DA5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAD53A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAD53A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C40A0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C40A0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  937.4064766 936.5730592
# elapsed time in seconds in face detection dengan 100 gambar : 0.833417
# hasil total: 4.561814 detik
# hasil tambahfinal:  4.561814
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAD59D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAD59D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B99FB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B99FB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B99FA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B99FA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  938.4721649 937.4077619
# elapsed time in seconds in face detection dengan 100 gambar : 1.064403
# hasil total: 5.626217 detik
# hasil tambahfinal:  5.626217
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468E8438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468E8438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F89AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634D9C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  939.476377 938.4732677
# elapsed time in seconds in face detection dengan 100 gambar : 1.003109
# hasil total: 6.629326 detik
# hasil tambahfinal:  6.629326
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468E8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468E8168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95057C438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95057C438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EDC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EDC168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  940.4464011 939.4775074
# elapsed time in seconds in face detection dengan 100 gambar : 0.968894
# hasil total: 7.598220 detik
# hasil tambahfinal:  7.598220
# >loaded 4 examples for class: admars
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95773FF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7164C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF7164C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96ABA2708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96ABA2708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  941.3103495 940.4478969
# elapsed time in seconds in face detection dengan 100 gambar : 0.862453
# hasil total: 8.460673 detik
# hasil tambahfinal:  8.460673
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CE0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CE0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAC30D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAC30D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96296AB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96296AB88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  942.2394377 941.3116333
# elapsed time in seconds in face detection dengan 100 gambar : 0.927804
# hasil total: 9.388477 detik
# hasil tambahfinal:  9.388477
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F731F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945F731F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DFF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DFF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951089678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951089678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  943.2473178 942.2405671
# elapsed time in seconds in face detection dengan 100 gambar : 1.006751
# hasil total: 10.395228 detik
# hasil tambahfinal:  10.395228
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DF168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9576DF168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962944558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962944558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E7A318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E7A318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  944.211475 943.2485298
# elapsed time in seconds in face detection dengan 100 gambar : 0.962945
# hasil total: 11.358173 detik
# hasil tambahfinal:  11.358173
# >loaded 4 examples for class: ahodki
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5F0AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94E5F0AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963493F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963493F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962944318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B962944318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  945.1122332 944.2128683
# elapsed time in seconds in face detection dengan 100 gambar : 0.899365
# hasil total: 12.257538 detik
# hasil tambahfinal:  12.257538
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E7A3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B891E7A3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950DECA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950DECA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E8BD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E8BD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  946.0108926 945.1132877
# elapsed time in seconds in face detection dengan 100 gambar : 0.897605
# hasil total: 13.155143 detik
# hasil tambahfinal:  13.155143
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950DE9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8950DE9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E5D8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E5D8B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C3438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89C3C3438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  946.9983928 946.0121238
# elapsed time in seconds in face detection dengan 100 gambar : 0.986269
# hasil total: 14.141412 detik
# hasil tambahfinal:  14.141412
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E8B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7E8B678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAD5AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAD5AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CE0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF4CE0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  948.1452509 946.9994769
# elapsed time in seconds in face detection dengan 100 gambar : 1.145774
# hasil total: 15.287186 detik
# hasil tambahfinal:  15.287186
# >loaded 4 examples for class: ajbake
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95104BDC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9468E8828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  1023.4135129 1022.4774619
# elapsed time in seconds in face detection dengan 100 gambar : 0.936051
# hasil total: 90.458949 detik
# hasil tambahfinal:  90.458949
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EDC0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8A7EDC0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951077828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B951077828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94692B0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B94692B0D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  1024.4478434 1023.4147299
# elapsed time in seconds in face detection dengan 100 gambar : 1.033114
# hasil total: 91.492062 detik
# hasil tambahfinal:  91.492062
# >loaded 4 examples for class: bschap
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FA50D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FA50D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963496D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B963496D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FA5828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B945FA5828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  1025.3174656 1024.4491124
# elapsed time in seconds in face detection dengan 100 gambar : 0.868353
# hasil total: 92.360415 detik
# hasil tambahfinal:  92.360415
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634963A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9634963A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF2B828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFF2B828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505DB438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9505DB438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  1026.2354511 1025.3187764
# elapsed time in seconds in face detection dengan 100 gambar : 0.916675
# hasil total: 93.277090 detik
# hasil tambahfinal:  93.277090
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89505F288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89505F288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89505F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B89505F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9BA048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B95B9BA048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  1027.2684013 1026.2365615
# elapsed time in seconds in face detection dengan 100 gambar : 1.031840
# hasil total: 94.308930 detik
# hasil tambahfinal:  94.308930
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAC9F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FFAC9F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF75C828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B8FF75C828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96C5E3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B96C5E3558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# elapsed time:  1028.3705983 1027.2697465
# elapsed time in seconds in face detection dengan 100 gambar : 1.100852
# hasil total: 95.409782 detik
# hasil tambahfinal:  95.409782
# >loaded 4 examples for class: cadugd
# Time:  95.53677700000003

# %%
Total = (tambahfinal1 + tambahfinal2 + tambahfinal3 + tambahfinal4 + tambahfinal5 + tambahfinal6 + tambahfinal7 + tambahfinal8 + tambahfinal9 + tambahfinal10) / 10


print('Total Eksperimen Face Detection MTCNN + FaceNet: %.6f Detik'% Total)
# Out:
# Total Eksperimen Face Detection MTCNN + FaceNet: 95.950725 Detik

# %% [markdown]
# ## Kecepatan Embedding

# %% [markdown]
# ### Embedding Speed MTCNN + FaceNet

# %%
# calculate a face embedding for each face in the dataset using facenet
from numpy import load
from numpy import expand_dims
from numpy import asarray
from numpy import savez_compressed
from keras.models import load_model
import cv2
import matplotlib.pyplot as plt
import numpy as np
import timeit
from timeit import default_timer as timer



# get the face embedding for one face
#dapetin fitur pixel wajah
temp = 0
def get_embedding(model, face_pixels):
	# scale pixel values
	face_pixels = face_pixels.astype('float32')
	# standardize pixel values across channels (global)
	mean, std = face_pixels.mean(), face_pixels.std()
	face_pixels = (face_pixels - mean) / std
	# transform face into one sample
	samples = expand_dims(face_pixels, axis=0)
	# make prediction to get embedding
	yhat = model.predict(samples)
	return yhat[0]

# load the face dataset
data = load('FaceNet+MTCNN+Faces96+Lengkap100.npz') # model yang digunakan untuk detect wajah

timeX,timey = data['arr_6'], data['arr_7']
print('Loaded: ',timeX.shape, timey.shape)
# load the facenet model



model = load_model('facenet_keras.h5') # arcface dengan input 112 ,112 , 3


print('Loaded Model')

start3 = timeit.default_timer()
newTimeX= list()
for face_pixels in timeX:
	embedding= get_embedding(model,face_pixels)
	newTimeX.append(embedding)

newTimeX= asarray(newTimeX)
stop = timeit.default_timer()
print(newTimeX.shape)

jumlah = stop-start3
print('elapsed time in seconds in feature extraction embedding wajah  MTCNN + FaceNet dengan 100 gambar : %f' % (jumlah))
# Out:
# Loaded:  (100, 160, 160, 3) (100,)
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Loaded Model
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9769F9CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001B9769F9CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (100, 128)
# elapsed time in seconds in feature extraction embedding wajah  MTCNN + FaceNet dengan 100 gambar : 7.881974

# %% [markdown]
# ## Recognition Speed

# %% [markdown]
# ### MTCNN + FaceNet

# %%
# develop a classifier for the 5 Celebrity Faces Dataset
from numpy import load
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.cluster import KMeans
from sklearn.gaussian_process import GaussianProcessClassifier
# example of creating a face embedding
#from keras_vggface.vggface import VGGFace
#from keras_vggface.utils import preprocess_input
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
# load dataset
#EMBEDDINGS DATA
data = load('FaceNet+MTCNN+Faces96+Lengkap100_embeddings.npz')
#trainX, trainy, testX, testy = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3']
trainX, trainy, testX, testy, valX,valy, timeX,timey = data['arr_0'], data['arr_1'], data['arr_2'], data['arr_3'], data['arr_4'], data['arr_5'], data['arr_6'], data['arr_7']
#print('Dataset: train=%d, test=%d' % (trainX.shape[0], testX.shape[0]))
print('Dataset: train=%d, test=%d, val=%d' % (trainX.shape[0], testX.shape[0], valX.shape[0]))
# normalize input vectors
in_encoder = Normalizer(norm='l2')

#####

#print(trainX)
trainX = in_encoder.transform(trainX)
testX = in_encoder.transform(testX)
valX= in_encoder.transform(valX)
timeX= in_encoder.transform(timeX)


modela= SVC(kernel='linear', probability=True)

out_encoder = LabelEncoder()

out_encoder.fit(trainy)



trainy = out_encoder.transform(trainy)
testy = out_encoder.transform(testy)
valy= out_encoder.transform(valy)
timey = out_encoder.transform(timey)

#####
# fit model

#MODEL
model = MLPClassifier(solver='adam',
                        hidden_layer_sizes=(512, 512),
                        activation='relu',
                        learning_rate_init=0.001,
                        verbose=True,
                        tol= 1e-100,
                        n_iter_no_change=5,
                        max_iter=100,
                        #early_stopping=True,
                        warm_start=True
                        )

history = modela.fit(trainX, trainy)
#print("test problem 0.8")
#MLPClassifier(activation= 'tanh',alpha= 0.05, hidden_layer_sizes= (100,), learning_rate= 'adaptive', solver= 'adam')
# ########################
# # parameter_space = {
# #     'criterion' : ['gini', 'entropy'],
# #     'splitter' : ['best', 'random'],
# #     'max_features' : ['auto', 'sqrt', 'log2'],
# # }
# # clf = GridSearchCV(model, parameter_space, n_jobs=-1, cv=2)
# # clf.fit(trainX, trainy)

# # # Best paramete set
# # print('Best parameters found:\n', clf.best_params_)

# # # All results
# # means = clf.cv_results_['mean_test_score']
# # stds = clf.cv_results_['std_test_score']
# # for mean, std, params in zip(means, stds, clf.cv_results_['params']):
# #     print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# #######################
#KNeighborsClassifier(n_neighbors=3)
#82
#KNeighborsClassifier(n_neighbors=3)

history = model.fit(trainX, trainy)
#print("test problem 0.9")
# predict
yhat_train = model.predict(trainX)
yhat_test = model.predict(testX)
yhat_val= model.predict(valX)
yhat_time=model.predict(timeX)
#print("test problem 1.0")
# score
score_train = accuracy_score(trainy, yhat_train)
score_test = accuracy_score(testy, yhat_test)
score_val= accuracy_score(valy, yhat_val)
score_time = accuracy_score(timey,yhat_time)
# summarize
#print('Accuracy: train=%.3f, test=%.3f' % (score_train*100, score_test*100)) #  RANK 1 ACCURACY
#print('Accuracy RetinaFace+ ArcFace: train=%.3f, test=%.3f, val=%.3f' % (score_train*100, score_test*100, score_val*100)) #  RANK 1 ACCURACY
# print('validation loss=%.3f, validation accuracy=%.3f' % (model.loss_, model.validation_scores_[-1]))

# summarize
print('Accuracy RetinaFace+ FaceNet: train=%.3f, test=%.3f, val=%.3f' % (score_train*100, score_test*100, score_val*100)) #  RANK 1 ACCURACY


# loss = model.loss_curve_
# val_score = model.validation_scores_
# iters = range(len(loss))
# plt.plot(iters, loss, 'r', label='validation loss')
# plt.title('validation loss')
# # plt.savefig('validation loss retinex dark_05.jpg')
# plt.legend()
# plt.figure()
# plt.plot(iters, val_score, 'b', label='Validation accuracy')
# plt.title('validation accuracy')
# # plt.savefig('validation accuracy retinex dark_05.jpg')
# plt.legend()
# plt.show()
# print(classification_report(yhat_test, testy))

# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']
# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs = range(len(acc))

# plt.plot(epochs, acc, 'r', label='Training accuracy')
# plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
# plt.title('Training and validation accuracy')
# plt.legend(loc=0)
# plt.figure()

# plt.show()

# accuracy: (tp + tn) / (p + n)z
# accuracy = accuracy_score(testy, yhat_test)
# print('Accuracy: %f' % (accuracy *100))
# # precision tp / (tp + fp)
# precision = precision_score(testy, yhat_test, pos_label='positive', average='micro')
# print('Precision: %f' % (precision *100))
# # recall: tp / (tp + fn)
# recall = recall_score(testy, yhat_test, pos_label='positive', average='micro')
# print('Recall: %f' % (recall *100))
# # f1: 2 tp / (2 tp + fp + fn)
# f1 = f1_score(testy, yhat_test, pos_label='positive', average='micro')
# print('F1 score: %f' % (f1 *100))

# print('Mean Absolute Error : ', mean_absolute_error(testy, yhat_test))
# print('Mean Squared Error  : ', mean_squared_error(testy, yhat_test))
# print('R2                  : ', r2_score(testy, yhat_test))
# y_true, y_pred = testy , clf.predict(testX)

# from sklearn.metrics import classification_report
# print('Results on the test set:')
# print(classification_report(y_true, y_pred))
# Out:
# Dataset: train=2714, test=908, val=902
# Iteration 1, loss = 5.33083228
# Iteration 2, loss = 4.95414515
# Iteration 3, loss = 4.15104614
# Iteration 4, loss = 2.62328517
# Iteration 5, loss = 0.89864029
# Iteration 6, loss = 0.21309498
# Iteration 7, loss = 0.09023808
# Iteration 8, loss = 0.06042510
# Iteration 9, loss = 0.05381683
# Iteration 10, loss = 0.04966619
# Iteration 11, loss = 0.04609199
# Iteration 12, loss = 0.04180820
# Iteration 13, loss = 0.03410557
# Iteration 14, loss = 0.03516183
# Iteration 15, loss = 0.02965137
# Iteration 16, loss = 0.02932259
# Iteration 17, loss = 0.02907099
# Iteration 18, loss = 0.02636715
# Iteration 19, loss = 0.02382078
# Iteration 20, loss = 0.02334460
# Iteration 21, loss = 0.02217708
# Iteration 22, loss = 0.02124701
# Iteration 23, loss = 0.02105024
# Iteration 24, loss = 0.01982633
# Iteration 25, loss = 0.01859973
# Iteration 26, loss = 0.01815711
# Iteration 27, loss = 0.01705739
# Iteration 28, loss = 0.01677316
# Iteration 29, loss = 0.01982861
# Iteration 30, loss = 0.01700058
# Iteration 31, loss = 0.01551842
# Iteration 32, loss = 0.01857343
# Iteration 33, loss = 0.01599884
# Iteration 34, loss = 0.01449114
# Iteration 35, loss = 0.01363879
# Iteration 36, loss = 0.01285474
# Iteration 37, loss = 0.01402550
# Iteration 38, loss = 0.01179744
# Iteration 39, loss = 0.01130392
# Iteration 40, loss = 0.01127129
# Iteration 41, loss = 0.01270482
# Iteration 42, loss = 0.01145847
# Iteration 43, loss = 0.00954389
# Iteration 44, loss = 0.01120383
# Iteration 45, loss = 0.00980907
# Iteration 46, loss = 0.00917183
# Iteration 47, loss = 0.00930173
# Iteration 48, loss = 0.00901393
# Iteration 49, loss = 0.01008604
# Iteration 50, loss = 0.00751494
# Iteration 51, loss = 0.00802423
# Iteration 52, loss = 0.00808400
# Iteration 53, loss = 0.00995935
# Iteration 54, loss = 0.00837850
# Iteration 55, loss = 0.00706931
# Iteration 56, loss = 0.00703357
# Iteration 57, loss = 0.00617718
# Iteration 58, loss = 0.00724938
# Iteration 59, loss = 0.00707854
# Iteration 60, loss = 0.00655658
# Iteration 61, loss = 0.00837432
# Iteration 62, loss = 0.00621222
# Iteration 63, loss = 0.00654928
# Training loss did not improve more than tol=0.000000 for 5 consecutive epochs. Stopping.
# Accuracy RetinaFace+ FaceNet: train=99.853, test=97.797, val=99.113

# %%
import timeit
from timeit import default_timer as timer
print('dataset test: ', timeX.shape[0])
startmtcnnfacenet = timer()
# history = modela.fit(trainX, trainy)
#print("test problem 0.9")
# predict
#yhat_train = model.predict(trainX)
#yhat_test = model.predict(testX)
# start2 = timer()
# start3 = timeit.default_timer()
yhat_time= modela.predict(timeX)
#yhat_val= model.predict(T)
#print("test problem 1.0")
# score
#score_train = accuracy_score(trainy, yhat_train)
#score_test = accuracy_score(testy, yhat_test)
score_timetest= accuracy_score(timey,yhat_time)
#score_val= accuracy_score(valy, yhat_val)
# summarize
#('Accuracy:  Test Kecepatan=%.3f' % (score_timetest*100)) #  RANK 1 ACCURACY
stopmtcnnfacenet = timeit.default_timer()
print('elapsed time in seconds in face recognition dengan 100 gambar : %f' % (stopmtcnnfacenet-startmtcnnfacenet))
# Out:
# dataset test:  100
# elapsed time in seconds in face recognition dengan 100 gambar : 0.129720
